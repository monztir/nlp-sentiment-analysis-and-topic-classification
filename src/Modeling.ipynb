# %% [markdown]
# # **Modeling**

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Section 1:** Modeling - IMDB (Sentiment Analysis)

# %% [markdown]
# ## **Section 2:** Modeling - 20Newsgroups (Topic Classification)
