# %% [markdown]
# # **Processing**

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Section 1:** Processing - IMDB

# %% [markdown]
# ## **Section 2:** Processing - 20Newsgroups
