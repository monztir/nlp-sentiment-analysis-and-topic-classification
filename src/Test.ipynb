# %% [markdown]
# # **Test**

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Section 1:** Test - IMDB (Sentiment Analysis)

# %% [markdown]
# ## **Section 2:** Test - 20Newsgroups (Sentiment Analysis)
